# %%
import pandas as pd
import time
import random

from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()


import pygame
from pygame import mixer

drogueria = {
    "Lavado de Ropa": "https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=",
    "Lavavajillas": "https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=",
    "Utensilios Limpieza": "https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=",
    # "Celulosas": "https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=",
    # "Lejías y Amoníacos": "https://www.alcampo.es/compra-online/drogueria/lejias-y-amoniacos/c/W2107?q=%3Arelevance&page=",
    # "Limpieza Calzado": "https://www.alcampo.es/compra-online/drogueria/limpieza-calzado/c/W2105?q=%3Arelevance&page=",
    # "Conservación de Alimentos y Moldes": "https://www.alcampo.es/compra-online/drogueria/conservacion-de-alimentos-y-moldes/c/W2102?q=%3Arelevance&page=",
    # "Limpieza Hogar": "https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=",
    # "Ambientadores": "https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=",
    # "Insecticidas" : "https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page="

}


dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in drogueria.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1

df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=0
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=1
# Category: 96 Name: 96 Image: 96 Price: 96 Stock 96
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=2
# Category: 144 Name: 144 Image: 144 Price: 144 Stock 144
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=3
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=4
# Category: 240 Name: 240 Image: 240 Price: 240 Stock 240
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=5
# Category: 288 Name: 288 Image: 288 Price: 288 Stock 288
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=6
# Category: 336 Name: 336 Image: 336 Price: 336 Stock 336
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=7
# Category: 362 Name: 362 Image: 362 Price: 362 Stock 362
# Lavado de Ropa https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=8
# No hay más ventanas
# Lavavajillas https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=0
# Category: 410 Name: 410 Image: 410 Price: 410 Stock 410
# Lavavajillas https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=1
# Category: 458 Name: 458 Image: 458 Price: 458 Stock 458
# Lavavajillas https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=2
# Category: 506 Name: 506 Image: 506 Price: 506 Stock 506
# Lavavajillas https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=3
# Category: 510 Name: 510 Image: 510 Price: 510 Stock 510
# Lavavajillas https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=4
# No hay más ventanas
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=0
# Category: 558 Name: 558 Image: 558 Price: 558 Stock 558
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=1
# Category: 606 Name: 606 Image: 606 Price: 606 Stock 606
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=2
# Category: 654 Name: 654 Image: 654 Price: 654 Stock 654
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=3
# Category: 702 Name: 702 Image: 702 Price: 702 Stock 702
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=4
# Category: 750 Name: 750 Image: 750 Price: 750 Stock 750
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=5
# Category: 798 Name: 798 Image: 798 Price: 798 Stock 798
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=6
# List index out of range
# List index out of range
# Category: 846 Name: 846 Image: 846 Price: 846 Stock 846
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=7
# List index out of range
# Category: 882 Name: 882 Image: 882 Price: 882 Stock 882
# Utensilios Limpieza https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=8
# No hay más ventanas
#                 Category                                               Name  \
# 0         Lavado de Ropa  Detergente en cápsulas para lavadora WIPP Powe...
# 1         Lavado de Ropa  Detergente en cápsulas para lavadora ARIEL ORI...
# 2         Lavado de Ropa  Perlas para lavadora perfumadas LENOR Unstoppa...
# 3         Lavado de Ropa  Detergente líquido para ropa SKIP ACTIVE CLEAN...
# 4         Lavado de Ropa  Suavizante concentrado Azul PRODUCTO ALCAMPO 8...
# ..                   ...                                                ...
# 877  Utensilios Limpieza    Gamuza de piel, talla grande, PRODUCTO ALCAMPO.
# 878  Utensilios Limpieza  Cepillo con flecos de algodón que no rallan, i...
# 879  Utensilios Limpieza  Guantes de látex y algodón talla pequeña 6-6 1...
# 880  Utensilios Limpieza  Guantes de látex y algodón especial baños tall...
# 881  Utensilios Limpieza         Cubo de basura Push Half metal ACTUEL 42 l
#
#                      Price Stock  \
# 0     9,83 €(0,30 €/Dosis)   Yes
# 1    20,25 €(0,45 €/Dosis)   Yes
# 2             (27,09 €/Kg)   Yes
# 3    22,94 €(0,23 €/Dosis)   Yes
# 4     1,94 €(0,97 €/Litro)   Yes
# ..                     ...   ...
# 877                 9,35 €   Yes
# 878                 6,95 €   Yes
# 879                 5,98 €   Yes
# 880                 5,98 €   Yes
# 881                34,50 €   Yes
#
#                                                  Image
# 0    https://www.alcampo.es/media/h76/he0/118641590...
# 1    https://www.alcampo.es/media/h40/h07/121178156...
# 2    https://www.alcampo.es/media/hf5/h90/121177847...
# 3    https://www.alcampo.es/media/hed/he3/117538479...
# 4    https://www.alcampo.es/media/h79/h17/934710031...
# ..                                                 ...
# 877  https://www.alcampo.es/media/hb1/hc5/924838425...
# 878  https://www.alcampo.es/media/h6e/h98/888580787...
# 879  https://www.alcampo.es/media/h3f/hd0/987343237...
# 880  https://www.alcampo.es/media/h74/hbe/987323472...
# 881  https://www.alcampo.es/media/h89/h68/954683198...
#
# [882 rows x 5 columns]

# %%
df_alcampo['Shop'] = 'Alcampo'

today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

alcampo = pd.read_csv("../data/alcampo.csv")
print(today)
alcampo
# Out:
# 2023-03-17 13:15:54.692511
#                    Category  \
# 0                   Veganos
# 1                   Veganos
# 2                   Veganos
# 3                   Veganos
# 4                   Veganos
# ...                     ...
# 179120  Utensilios Limpieza
# 179121  Utensilios Limpieza
# 179122  Utensilios Limpieza
# 179123  Utensilios Limpieza
# 179124  Utensilios Limpieza
#
#                                                      Name  \
# 0       Bebida de avena con alto contenido de calcio y...
# 1       Bebida de soja sin gluten, enriquecida con cal...
# 2       Bebida de avena con alto contenido de calcio y...
# 3       Bebida de almendras 100% vegetal, sin azúcar n...
# 4       Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...                                                   ...
# 179120    Gamuza de piel, talla grande, PRODUCTO ALCAMPO.
# 179121  Cepillo con flecos de algodón que no rallan, i...
# 179122  Guantes de látex y algodón talla pequeña 6-6 1...
# 179123  Guantes de látex y algodón especial baños tall...
# 179124         Cubo de basura Push Half metal ACTUEL 42 l
#
#                         Price Stock  \
# 0        5,94 €(0,99 €/Litro)   Yes
# 1        5,34 €(0,89 €/Litro)   Yes
# 2        0,99 €(0,99 €/Litro)   Yes
# 3        2,10 €(2,10 €/Litro)   Yes
# 4       11,22 €(0,18 €/100ml)   Yes
# ...                       ...   ...
# 179120                 9,35 €   Yes
# 179121                 6,95 €   Yes
# 179122                 5,98 €   Yes
# 179123                 5,98 €   Yes
# 179124                34,50 €   Yes
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 179120  https://www.alcampo.es/media/hb1/hc5/924838425...  Alcampo
# 179121  https://www.alcampo.es/media/h6e/h98/888580787...  Alcampo
# 179122  https://www.alcampo.es/media/h3f/hd0/987343237...  Alcampo
# 179123  https://www.alcampo.es/media/h74/hbe/987323472...  Alcampo
# 179124  https://www.alcampo.es/media/h89/h68/954683198...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 179120  2023-03-17 13:15:54.692511
# 179121  2023-03-17 13:15:54.692511
# 179122  2023-03-17 13:15:54.692511
# 179123  2023-03-17 13:15:54.692511
# 179124  2023-03-17 13:15:54.692511
#
# [179125 rows x 7 columns]
