# %%
import pandas as pd
import time
import random

from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()
import pygame
from pygame import mixer


drogueria = {
    # "Lavado de Ropa": "https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=",
    # "Lavavajillas": "https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=",
    # "Utensilios Limpieza": "https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=",
    "Celulosas": "https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=",
    "Lejías y Amoníacos": "https://www.alcampo.es/compra-online/drogueria/lejias-y-amoniacos/c/W2107?q=%3Arelevance&page=",
    "Limpieza Calzado": "https://www.alcampo.es/compra-online/drogueria/limpieza-calzado/c/W2105?q=%3Arelevance&page=",
    # "Conservación de Alimentos y Moldes": "https://www.alcampo.es/compra-online/drogueria/conservacion-de-alimentos-y-moldes/c/W2102?q=%3Arelevance&page=",
    # "Limpieza Hogar": "https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=",
    # "Ambientadores": "https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=",
    # "Insecticidas" : "https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page="

}


dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in drogueria.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1

df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Celulosas https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=0
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Celulosas https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=1
# Category: 96 Name: 96 Image: 96 Price: 96 Stock 96
# Celulosas https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=2
# Category: 144 Name: 144 Image: 144 Price: 144 Stock 144
# Celulosas https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=3
# Category: 155 Name: 155 Image: 155 Price: 155 Stock 155
# Celulosas https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=4
# No hay más ventanas
# Lejías y Amoníacos https://www.alcampo.es/compra-online/drogueria/lejias-y-amoniacos/c/W2107?q=%3Arelevance&page=0
# Category: 203 Name: 203 Image: 203 Price: 203 Stock 203
# Lejías y Amoníacos https://www.alcampo.es/compra-online/drogueria/lejias-y-amoniacos/c/W2107?q=%3Arelevance&page=1
# Category: 208 Name: 208 Image: 208 Price: 208 Stock 208
# Lejías y Amoníacos https://www.alcampo.es/compra-online/drogueria/lejias-y-amoniacos/c/W2107?q=%3Arelevance&page=2
# No hay más ventanas
# Limpieza Calzado https://www.alcampo.es/compra-online/drogueria/limpieza-calzado/c/W2105?q=%3Arelevance&page=0
# Category: 256 Name: 256 Image: 256 Price: 256 Stock 256
# Limpieza Calzado https://www.alcampo.es/compra-online/drogueria/limpieza-calzado/c/W2105?q=%3Arelevance&page=1
# Category: 289 Name: 289 Image: 289 Price: 289 Stock 289
# Limpieza Calzado https://www.alcampo.es/compra-online/drogueria/limpieza-calzado/c/W2105?q=%3Arelevance&page=2
# No hay más ventanas
#              Category                                               Name  \
# 0           Celulosas  Papel higiénico compacto de doble capa PRODUCT...
# 1           Celulosas  Papel higiénico de doble capa PRODUCTO ALCAMPO...
# 2           Celulosas  Papel de cocina multiusos gigante, doble capa ...
# 3           Celulosas  Pañuelos de celulosa PRODUCTO ALCAMPO 24 paque...
# 4           Celulosas  Papel de cocina decorado Jumbo PRODUCTO ALCAMP...
# ..                ...                                                ...
# 284  Limpieza Calzado  Talonera gel dual para hombre ACHUCHONAS, auto...
# 285  Limpieza Calzado  Plantillas gel liquido ACHUCHONAS, relajantes,...
# 286  Limpieza Calzado  Plantillas Memory antiolor ACHUCHONAS, carbón ...
# 287  Limpieza Calzado  Talonera gel dual para mujer ACHUCHONAS, autoa...
# 288  Limpieza Calzado  Plantillas gel dual ACHUCHONAS, amortiguación,...
#
#                      Price Stock  \
# 0    4,99 €(0,42 €/Unidad)   Yes
# 1    2,54 €(0,21 €/Unidad)   Yes
# 2     3,99 €(0,02 €/Metro)   Yes
# 3    2,95 €(0,12 €/Unidad)   Yes
# 4     3,09 €(0,03 €/Metro)   Yes
# ..                     ...   ...
# 284                 8,99 €   Yes
# 285                 4,99 €   Yes
# 286                 8,99 €   Yes
# 287                 8,99 €   Yes
# 288                 9,99 €   Yes
#
#                                                  Image
# 0    https://www.alcampo.es/media/h5f/hdc/104228477...
# 1    https://www.alcampo.es/media/h5d/h26/962738002...
# 2    https://www.alcampo.es/media/he1/h64/968772098...
# 3    https://www.alcampo.es/media/hd8/h3c/104598373...
# 4    https://www.alcampo.es/media/hd6/h1c/972143814...
# ..                                                 ...
# 284  https://www.alcampo.es/media/h16/h8e/110187054...
# 285  https://www.alcampo.es/media/h08/hcc/110187016...
# 286  https://www.alcampo.es/media/ha1/h6c/110186835...
# 287  https://www.alcampo.es/media/h5b/h73/110187023...
# 288  https://www.alcampo.es/media/he9/hfd/110186981...
#
# [289 rows x 5 columns]

# %%
df_alcampo['Shop'] = 'Alcampo'

today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

alcampo = pd.read_csv("../data/alcampo.csv")
print(today)
alcampo
# Out:
# 2023-03-17 13:14:54.870992
#                 Category                                               Name  \
# 0                Veganos  Bebida de avena con alto contenido de calcio y...
# 1                Veganos  Bebida de soja sin gluten, enriquecida con cal...
# 2                Veganos  Bebida de avena con alto contenido de calcio y...
# 3                Veganos  Bebida de almendras 100% vegetal, sin azúcar n...
# 4                Veganos  Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...                  ...                                                ...
# 174672  Limpieza Calzado  Talonera gel dual para hombre ACHUCHONAS, auto...
# 174673  Limpieza Calzado  Plantillas gel liquido ACHUCHONAS, relajantes,...
# 174674  Limpieza Calzado  Plantillas Memory antiolor ACHUCHONAS, carbón ...
# 174675  Limpieza Calzado  Talonera gel dual para mujer ACHUCHONAS, autoa...
# 174676  Limpieza Calzado  Plantillas gel dual ACHUCHONAS, amortiguación,...
#
#                         Price Stock  \
# 0        5,94 €(0,99 €/Litro)   Yes
# 1        5,34 €(0,89 €/Litro)   Yes
# 2        0,99 €(0,99 €/Litro)   Yes
# 3        2,10 €(2,10 €/Litro)   Yes
# 4       11,22 €(0,18 €/100ml)   Yes
# ...                       ...   ...
# 174672                 8,99 €   Yes
# 174673                 4,99 €   Yes
# 174674                 8,99 €   Yes
# 174675                 8,99 €   Yes
# 174676                 9,99 €   Yes
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 174672  https://www.alcampo.es/media/h16/h8e/110187054...  Alcampo
# 174673  https://www.alcampo.es/media/h08/hcc/110187016...  Alcampo
# 174674  https://www.alcampo.es/media/ha1/h6c/110186835...  Alcampo
# 174675  https://www.alcampo.es/media/h5b/h73/110187023...  Alcampo
# 174676  https://www.alcampo.es/media/he9/hfd/110186981...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 174672  2023-03-17 13:14:54.870992
# 174673  2023-03-17 13:14:54.870992
# 174674  2023-03-17 13:14:54.870992
# 174675  2023-03-17 13:14:54.870992
# 174676  2023-03-17 13:14:54.870992
#
# [174677 rows x 7 columns]
