# %%
import pandas as pd
import time
import random


from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()




alimentacion = {
    # "Leche Huevos Yogures y Lácteos": "https://www.alcampo.es/compra-online/alimentacion/leche-huevos-yogures-y-lacteos/c/W16?q=%3Arelevance&page=",
    "Aceite Vinagre Salsas Especias" : "https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=",
    # "Desayuno y Merienda": "https://www.alcampo.es/compra-online/alimentacion/desayuno-y-merienda/c/W10?q=%3Arelevance&page=",
    # "Conservas": "https://www.alcampo.es/compra-online/alimentacion/conservas/c/W1004?q=%3Arelevance&page=",
    # "Comida Internacional":"https://www.alcampo.es/compra-online/alimentacion/comida-internacional/c/W9410?q=%3Arelevance&page=",
    # "Aperitivos, aceitunas y frutos secos": "https://www.alcampo.es/compra-online/alimentacion/aperitivos-aceitunas-y-frutos-secos/c/W120?q=%3Arelevance&page=",
    # "Nutrición deportiva":"https://www.alcampo.es/compra-online/alimentacion/nutricion-deportiva/c/W12?q=%3Arelevance&page=",
    # "Caldos, Pasta, Arroz Legumbres Puré":"https://www.alcampo.es/compra-online/alimentacion/caldos-pasta-arroz-legumbres-pure/c/W140?q=%3Arelevance&page=",
    # "Azúcar Harina Masas y Pan": "https://www.alcampo.es/compra-online/alimentacion/azucar-harina-masas-y-pan/c/W1009?q=%3Arelevance&page=",
    # "Alimentos Especiales": "https://www.alcampo.es/compra-online/alimentacion/alimentos-especiales-/c/W33?q=%3Arelevance&page=",
    # "Veganos": "https://www.alcampo.es/compra-online/alimentacion/veganos/c/W09112021?q=%3Arelevance&page=",
    # "Supermercado Ecológico": "https://www.alcampo.es/compra-online/alimentacion/supermercado-ecologico/c/W26112021?q=%3Arelevance&page="
}



dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in alimentacion.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1

df_alcampo = pd.DataFrame(dict_alcampo)

df_alcampo
# Out:
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=0
# Got an attribute error on: https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=0
# Category: 0 Name: 0 Image: 0 Price: 0 Stock 0
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=1
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=2
# Category: 96 Name: 96 Image: 96 Price: 96 Stock 96
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=3
# Category: 144 Name: 144 Image: 144 Price: 144 Stock 144
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=4
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=5
# Got an attribute error on: https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=5
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=6
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=7
# Category: 240 Name: 240 Image: 240 Price: 240 Stock 240
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=8
# Category: 288 Name: 288 Image: 288 Price: 288 Stock 288
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=9
# Category: 336 Name: 336 Image: 336 Price: 336 Stock 336
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=10
# Category: 384 Name: 384 Image: 384 Price: 384 Stock 384
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=11
# Category: 432 Name: 432 Image: 432 Price: 432 Stock 432
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=12
# Category: 480 Name: 480 Image: 480 Price: 480 Stock 480
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=13
# Category: 528 Name: 528 Image: 528 Price: 528 Stock 528
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=14
# Got an attribute error on: https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=14
# Category: 528 Name: 528 Image: 528 Price: 528 Stock 528
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=15
# Got an attribute error on: https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=15
# Category: 528 Name: 528 Image: 528 Price: 528 Stock 528
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=16
# Got an attribute error on: https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=16
# Category: 528 Name: 528 Image: 528 Price: 528 Stock 528
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=17
# Got an attribute error on: https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=17
# Category: 528 Name: 528 Image: 528 Price: 528 Stock 528
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=18
# Category: 576 Name: 576 Image: 576 Price: 576 Stock 576
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=19
# Category: 618 Name: 618 Image: 618 Price: 618 Stock 618
# Aceite Vinagre Salsas Especias https://www.alcampo.es/compra-online/alimentacion/aceite-vinagre-salsas-especias/c/W18?q=%3Arelevance&page=20
# No hay más ventanas
#                            Category  \
# 0    Aceite Vinagre Salsas Especias
# 1    Aceite Vinagre Salsas Especias
# 2    Aceite Vinagre Salsas Especias
# 3    Aceite Vinagre Salsas Especias
# 4    Aceite Vinagre Salsas Especias
# ..                              ...
# 613  Aceite Vinagre Salsas Especias
# 614  Aceite Vinagre Salsas Especias
# 615  Aceite Vinagre Salsas Especias
# 616  Aceite Vinagre Salsas Especias
# 617  Aceite Vinagre Salsas Especias
#
#                                                   Name                  Price  \
# 0                 Tomate frito ORLANDO pack 6 x 350 g.      3,99 €(1,90 €/Kg)
# 1    Tomate frito 0,0, sin sal y sin azúcar añadido...      1,32 €(3,77 €/Kg)
# 2                  Aceite refinado de girasol BAU 1 l.   2,40 €(2,40 €/Litro)
# 3                                        Acumula saldo  32,99 €(6,59 €/Litro)
# 4                    Mayonesa YBARRA frasco de 450 ml.   2,24 €(4,97 €/Litro)
# ..                                                 ...                    ...
# 613              Canela en rama (5 ramas) DUCROS 22 g.                 4,99 €
# 614  Aceite de oliva virgen extra OLIVO DE CAMBIL f...  5,09 €(10,18 €/Litro)
# 615  Botánicos para preparar gintonics CARMENCITA C...                 4,04 €
# 616                     Pimienta rosa CARMENCITA 40 g.                 3,21 €
# 617  Aceite de oliva virgen extra procedente de oli...  19,59 €(7,83 €/Litro)
#
#     Stock                                              Image
# 0     Yes  https://www.alcampo.es/media/hf4/h78/115372374...
# 1     Yes  https://www.alcampo.es/media/hce/h6a/110872844...
# 2     Yes  https://www.alcampo.es/media/h2b/h54/107912462...
# 3     Yes  /compra-online/_ui/desktop/common/images/promo...
# 4     Yes  https://www.alcampo.es/media/h94/hc2/120150452...
# ..    ...                                                ...
# 613   Yes  https://www.alcampo.es/media/h6e/h90/105643956...
# 614   Yes  https://www.alcampo.es/media/h65/h33/946508958...
# 615   Yes  https://www.alcampo.es/media/hb2/hdd/896008146...
# 616   Yes  https://www.alcampo.es/media/hcc/h32/889653015...
# 617   Yes  https://www.alcampo.es/media/hf0/h4f/104376753...
#
# [618 rows x 5 columns]

# %%
# Add Alcampo name
df_alcampo['Shop'] = 'Alcampo'

# Add timestamp
today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

# Append to existing csv file
df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# Read in csv to save as excel as well
read_file = pd.read_csv ("../data/alcampo.csv")
read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

# Read Alcampo csv
alcampo = pd.read_csv("../data/alcampo.csv")
alcampo
# Out:
#                             Category  \
# 0                            Veganos
# 1                            Veganos
# 2                            Veganos
# 3                            Veganos
# 4                            Veganos
# ...                              ...
# 8101  Aceite Vinagre Salsas Especias
# 8102  Aceite Vinagre Salsas Especias
# 8103  Aceite Vinagre Salsas Especias
# 8104  Aceite Vinagre Salsas Especias
# 8105  Aceite Vinagre Salsas Especias
#
#                                                    Name  \
# 0     Bebida de avena con alto contenido de calcio y...
# 1     Bebida de soja sin gluten, enriquecida con cal...
# 2     Bebida de avena con alto contenido de calcio y...
# 3     Bebida de almendras 100% vegetal, sin azúcar n...
# 4     Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...                                                 ...
# 8101              Canela en rama (5 ramas) DUCROS 22 g.
# 8102  Aceite de oliva virgen extra OLIVO DE CAMBIL f...
# 8103  Botánicos para preparar gintonics CARMENCITA C...
# 8104                     Pimienta rosa CARMENCITA 40 g.
# 8105  Aceite de oliva virgen extra procedente de oli...
#
#                       Price Stock  \
# 0      5,94 €(0,99 €/Litro)   Yes
# 1      5,34 €(0,89 €/Litro)   Yes
# 2      0,99 €(0,99 €/Litro)   Yes
# 3      2,10 €(2,10 €/Litro)   Yes
# 4     11,22 €(0,18 €/100ml)   Yes
# ...                     ...   ...
# 8101                 4,99 €   Yes
# 8102  5,09 €(10,18 €/Litro)   Yes
# 8103                 4,04 €   Yes
# 8104                 3,21 €   Yes
# 8105  19,59 €(7,83 €/Litro)   Yes
#
#                                                   Image     Shop  \
# 0     https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1     https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2     https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3     https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4     https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                 ...      ...
# 8101  https://www.alcampo.es/media/h6e/h90/105643956...  Alcampo
# 8102  https://www.alcampo.es/media/h65/h33/946508958...  Alcampo
# 8103  https://www.alcampo.es/media/hb2/hdd/896008146...  Alcampo
# 8104  https://www.alcampo.es/media/hcc/h32/889653015...  Alcampo
# 8105  https://www.alcampo.es/media/hf0/h4f/104376753...  Alcampo
#
#                             Date
# 0     2023-03-08 19:51:25.159831
# 1     2023-03-08 19:51:25.159831
# 2     2023-03-08 19:51:25.159831
# 3     2023-03-08 19:51:25.159831
# 4     2023-03-08 19:51:25.159831
# ...                          ...
# 8101  2023-03-09 17:02:13.443707
# 8102  2023-03-09 17:02:13.443707
# 8103  2023-03-09 17:02:13.443707
# 8104  2023-03-09 17:02:13.443707
# 8105  2023-03-09 17:02:13.443707
#
# [8106 rows x 7 columns]
