# %%
import pandas as pd
import time
import random


from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()

import pygame
from pygame import mixer


cuidadoPersonal = {
    # "Cuidado del cabello" : "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-del-cabello/c/W701?q=%3Arelevance&page=",
    # "Desodorantes" : "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/desodorantes/c/W705?q=%3Arelevance&page=",
    # "Maquillaje": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/maquillaje/c/W708?q=%3Arelevance&page=",

    # "Neceseres": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/neceseres/c/W70011?q=%3Arelevance&page=",
    # "Cuidado corporal": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=",
    # "Cuidado facial": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-facial/c/W706?q=%3Arelevance&page=",

    # "Depilación": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/depilacion/c/W709?q=%3Arelevance&page=",
    # "Colonias": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=",
    # "Higiene bucal": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=",
    
    "Afeitado y cuidado masculino": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=",
    "Higiene íntima": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=",
    "Solares":"https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/solares/c/W70012?q=%3Arelevance&page="

}



dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in cuidadoPersonal.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1
    


df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Afeitado y cuidado masculino https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=0
# Got an attribute error on: https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=0
# Category: 0 Name: 0 Image: 0 Price: 0 Stock 0
# Afeitado y cuidado masculino https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=1
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Afeitado y cuidado masculino https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=2
# Got an attribute error on: https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=2
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Afeitado y cuidado masculino https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=3
# List index out of range
# Category: 75 Name: 75 Image: 75 Price: 75 Stock 75
# Afeitado y cuidado masculino https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=4
# No hay más ventanas
# Higiene íntima https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=0
# Category: 123 Name: 123 Image: 123 Price: 123 Stock 123
# Higiene íntima https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=1
# Category: 171 Name: 171 Image: 171 Price: 171 Stock 171
# Higiene íntima https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=2
# Category: 219 Name: 219 Image: 219 Price: 219 Stock 219
# Higiene íntima https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=3
# Category: 267 Name: 267 Image: 267 Price: 267 Stock 267
# Higiene íntima https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=4
# Category: 297 Name: 297 Image: 297 Price: 297 Stock 297
# Higiene íntima https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=5
# No hay más ventanas
# Solares https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/solares/c/W70012?q=%3Arelevance&page=0
# Category: 334 Name: 334 Image: 334 Price: 334 Stock 334
# Solares https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/solares/c/W70012?q=%3Arelevance&page=1
# No hay más ventanas
#                          Category  \
# 0    Afeitado y cuidado masculino
# 1    Afeitado y cuidado masculino
# 2    Afeitado y cuidado masculino
# 3    Afeitado y cuidado masculino
# 4    Afeitado y cuidado masculino
# ..                            ...
# 329                       Solares
# 330                       Solares
# 331                       Solares
# 332                       Solares
# 333                       Solares
#
#                                                   Name  \
# 0    Espuma de afeitar hidratante y protectora para...
# 1    Maquinilla de afeitar desechable con 3 hojas B...
# 2    Maquinilla de afeitar desechable, con cabezal ...
# 3    Recambio de cuchillas de 5 hojas antifricción ...
# 4    Contorno de ojos hidratante y que ayuda a redu...
# ..                                                 ...
# 329  Crema solar tipo BB cream, con tacto seco y FP...
# 330  Protector solar facial con factor de protecció...
# 331  Crema solar protectora, antimanchas y unificad...
# 332  Crema solar protectora anti imperfecciones y b...
# 333  Crema solar protectora con tono, antimanchas y...
#
#                       Price Stock  \
# 0      1,25 €(0,62 €/100ml)   Yes
# 1     5,22 €(0,52 €/Unidad)   Yes
# 2     4,65 €(0,78 €/Unidad)    No
# 3    38,99 €(4,87 €/Unidad)   Yes
# 4                   12,38 €   Yes
# ..                      ...   ...
# 329  16,99 €(33,98 €/100ml)   Yes
# 330                 13,48 €   Yes
# 331  25,60 €(51,20 €/100ml)   Yes
# 332  32,01 €(64,02 €/100ml)   Yes
# 333  25,60 €(51,20 €/100ml)   Yes
#
#                                                  Image
# 0    https://www.alcampo.es/media/h8a/h9f/910762131...
# 1    https://www.alcampo.es/media/h7e/hed/105979654...
# 2    https://www.alcampo.es/media/h66/hc1/951880594...
# 3    https://www.alcampo.es/media/hea/hc7/116180561...
# 4    https://www.alcampo.es/media/hf0/h06/109136694...
# ..                                                 ...
# 329  https://www.alcampo.es/media/haf/h02/997748408...
# 330  https://www.alcampo.es/media/he1/h3c/979391034...
# 331  https://www.alcampo.es/media/h18/hdd/115421955...
# 332  https://www.alcampo.es/media/hac/h67/115421928...
# 333  https://www.alcampo.es/media/h7e/h2b/115421983...
#
# [334 rows x 5 columns]

# %%
# Add Alcampo name
df_alcampo['Shop'] = 'Alcampo'

# Add timestamp
today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

# Append to existing csv file
df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# Read in csv to save as excel as well
# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

# Read Alcampo csv
alcampo = pd.read_csv("../data/alcampo.csv")
print("Appended",today)
alcampo
# Out:
# Appended 2023-03-13 20:29:49.969388
#        Category                                               Name  \
# 0       Veganos  Bebida de avena con alto contenido de calcio y...
# 1       Veganos  Bebida de soja sin gluten, enriquecida con cal...
# 2       Veganos  Bebida de avena con alto contenido de calcio y...
# 3       Veganos  Bebida de almendras 100% vegetal, sin azúcar n...
# 4       Veganos  Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...         ...                                                ...
# 104108  Solares  Crema solar tipo BB cream, con tacto seco y FP...
# 104109  Solares  Protector solar facial con factor de protecció...
# 104110  Solares  Crema solar protectora, antimanchas y unificad...
# 104111  Solares  Crema solar protectora anti imperfecciones y b...
# 104112  Solares  Crema solar protectora con tono, antimanchas y...
#
#                          Price Stock  \
# 0         5,94 €(0,99 €/Litro)   Yes
# 1         5,34 €(0,89 €/Litro)   Yes
# 2         0,99 €(0,99 €/Litro)   Yes
# 3         2,10 €(2,10 €/Litro)   Yes
# 4        11,22 €(0,18 €/100ml)   Yes
# ...                        ...   ...
# 104108  16,99 €(33,98 €/100ml)   Yes
# 104109                 13,48 €   Yes
# 104110  25,60 €(51,20 €/100ml)   Yes
# 104111  32,01 €(64,02 €/100ml)   Yes
# 104112  25,60 €(51,20 €/100ml)   Yes
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 104108  https://www.alcampo.es/media/haf/h02/997748408...  Alcampo
# 104109  https://www.alcampo.es/media/he1/h3c/979391034...  Alcampo
# 104110  https://www.alcampo.es/media/h18/hdd/115421955...  Alcampo
# 104111  https://www.alcampo.es/media/hac/h67/115421928...  Alcampo
# 104112  https://www.alcampo.es/media/h7e/h2b/115421983...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 104108  2023-03-13 20:29:49.969388
# 104109  2023-03-13 20:29:49.969388
# 104110  2023-03-13 20:29:49.969388
# 104111  2023-03-13 20:29:49.969388
# 104112  2023-03-13 20:29:49.969388
#
# [104113 rows x 7 columns]
