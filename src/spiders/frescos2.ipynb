# %%
import pandas as pd
import time
import random

from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()

import pygame
from pygame import mixer

frescos = {
    # "Frutas": "https://www.alcampo.es/compra-online/frescos/frutas/c/W1701?q=%3Arelevance&page=",
    # "Carne": "https://www.alcampo.es/compra-online/frescos/carne/c/W13?q=%3Arelevance&page=",
    # "Panadería":"https://www.alcampo.es/compra-online/frescos/panaderia/c/W1281?q=%3Arelevance&page=",
    "Verduras y hortalizas":"https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=",
    "Charcutería":"https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=",
    "Pastelería":"https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=",
    "Sushi": "https://www.alcampo.es/compra-online/frescos/sushi/c/W140502?q=%3Arelevance&page=",
    # "Quesos": "https://www.alcampo.es/compra-online/frescos/quesos/c/WQuesos?q=%3Arelevance&page=",
    # "Pescados, mariscos y moluscos": "https://www.alcampo.es/compra-online/frescos/pescados-mariscos-y-moluscos/c/W14?q=%3Arelevance&page=",
    # "Ahumados, sucedáneos gulas, anchoas": "https://www.alcampo.es/compra-online/frescos/ahumados-sucedaneos-gulas-anchoas/c/W184?q=%3Arelevance&page=",
    # "Fresco al Corte": "https://www.alcampo.es/compra-online/frescos/fresco-al-corte/c/WFrescoalcorte?q=%3Arelevance&page="
}



dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in frescos.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1

df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=0
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=1
# Category: 96 Name: 96 Image: 96 Price: 96 Stock 96
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=2
# Got an attribute error on: https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=2
# Category: 96 Name: 96 Image: 96 Price: 96 Stock 96
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=3
# Category: 144 Name: 144 Image: 144 Price: 144 Stock 144
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=4
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=5
# Category: 240 Name: 240 Image: 240 Price: 240 Stock 240
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=6
# Got an attribute error on: https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=6
# Category: 240 Name: 240 Image: 240 Price: 240 Stock 240
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=7
# Category: 288 Name: 288 Image: 288 Price: 288 Stock 288
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=8
# Category: 299 Name: 299 Image: 299 Price: 299 Stock 299
# Verduras y hortalizas https://www.alcampo.es/compra-online/frescos/verduras-y-hortalizas/c/W1702?q=%3Arelevance&page=9
# No hay más ventanas
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=0
# Category: 347 Name: 347 Image: 347 Price: 347 Stock 347
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=1
# Category: 395 Name: 395 Image: 395 Price: 395 Stock 395
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=2
# Got an attribute error on: https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=2
# Category: 395 Name: 395 Image: 395 Price: 395 Stock 395
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=3
# Category: 443 Name: 443 Image: 443 Price: 443 Stock 443
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=4
# Category: 491 Name: 491 Image: 491 Price: 491 Stock 491
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=5
# Category: 539 Name: 539 Image: 539 Price: 539 Stock 539
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=6
# Category: 587 Name: 587 Image: 587 Price: 587 Stock 587
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=7
# Category: 635 Name: 635 Image: 635 Price: 635 Stock 635
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=8
# Category: 683 Name: 683 Image: 683 Price: 683 Stock 683
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=9
# Category: 731 Name: 731 Image: 731 Price: 731 Stock 731
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=10
# Category: 778 Name: 778 Image: 778 Price: 778 Stock 778
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=11
# Category: 826 Name: 826 Image: 826 Price: 826 Stock 826
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=12
# Category: 874 Name: 874 Image: 874 Price: 874 Stock 874
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=13
# Category: 922 Name: 922 Image: 922 Price: 922 Stock 922
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=14
# Category: 970 Name: 970 Image: 970 Price: 970 Stock 970
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=15
# Category: 1018 Name: 1018 Image: 1018 Price: 1018 Stock 1018
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=16
# Category: 1066 Name: 1066 Image: 1066 Price: 1066 Stock 1066
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=17
# Got an attribute error on: https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=17
# Category: 1066 Name: 1066 Image: 1066 Price: 1066 Stock 1066
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=18
# Category: 1114 Name: 1114 Image: 1114 Price: 1114 Stock 1114
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=19
# Category: 1162 Name: 1162 Image: 1162 Price: 1162 Stock 1162
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=20
# Category: 1210 Name: 1210 Image: 1210 Price: 1210 Stock 1210
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=21
# Category: 1218 Name: 1218 Image: 1218 Price: 1218 Stock 1218
# Charcutería https://www.alcampo.es/compra-online/frescos/charcuteria/c/W15?q=%3Arelevance&page=22
# No hay más ventanas
# Pastelería https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=0
# Category: 1266 Name: 1266 Image: 1266 Price: 1266 Stock 1266
# Pastelería https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=1
# Category: 1314 Name: 1314 Image: 1314 Price: 1314 Stock 1314
# Pastelería https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=2
# Category: 1362 Name: 1362 Image: 1362 Price: 1362 Stock 1362
# Pastelería https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=3
# Category: 1410 Name: 1410 Image: 1410 Price: 1410 Stock 1410
# Pastelería https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=4
# Got an attribute error on: https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=4
# Category: 1410 Name: 1410 Image: 1410 Price: 1410 Stock 1410
# Pastelería https://www.alcampo.es/compra-online/frescos/pasteleria/c/W1282?q=%3Arelevance&page=5
# No hay más ventanas
# Sushi https://www.alcampo.es/compra-online/frescos/sushi/c/W140502?q=%3Arelevance&page=0
# Category: 1450 Name: 1450 Image: 1450 Price: 1450 Stock 1450
# Sushi https://www.alcampo.es/compra-online/frescos/sushi/c/W140502?q=%3Arelevance&page=1
# No hay más ventanas
#                    Category  \
# 0     Verduras y hortalizas
# 1     Verduras y hortalizas
# 2     Verduras y hortalizas
# 3     Verduras y hortalizas
# 4     Verduras y hortalizas
# ...                     ...
# 1445                  Sushi
# 1446                  Sushi
# 1447                  Sushi
# 1448                  Sushi
# 1449                  Sushi
#
#                                                    Name               Price  \
# 0                              Calabacín malla de 1 kg.   2,29 €(2,29 €/Kg)
# 1     Champiñones Portobello ALCAMPO PRODUCCIÓN CONT...         (4,76 €/Kg)
# 2     Calabacín ECO ALCAMPO PRODUCCIÓN CONTROLADA 60...   2,29 €(3,81 €/Kg)
# 3     Brotes de lechugas verdes y brote de lechuga r...        (12,60 €/Kg)
# 4                                         Acumula saldo      1€(20,00 €/Kg)
# ...                                                 ...                 ...
# 1445  Bandeja con 13 piezas de sushi variado MOWI 33...  8,90 €(26,33 €/Kg)
# 1446  California de Salmón y surimi, con cebolla fri...  7,50 €(37,50 €/Kg)
# 1447  Bandeja con Gyozas (empanadillas) de langostin...  3,50 €(40,69 €/Kg)
# 1448   Maki y California variados SUSHI GOURMET 18 uds.  7,90 €(29,25 €/Kg)
# 1449  Bandeja con 6 piezas de sushi variado MOWI 151 g.  4,90 €(32,45 €/Kg)
#
#      Stock                                              Image
# 0      Yes  https://www.alcampo.es/media/hcf/h5f/922000130...
# 1      Yes  https://www.alcampo.es/media/h6a/h7b/117538513...
# 2      Yes  https://www.alcampo.es/media/h14/hd7/118909605...
# 3      Yes  https://www.alcampo.es/media/hbc/hca/988855779...
# 4      Yes  /compra-online/_ui/desktop/common/images/promo...
# ...    ...                                                ...
# 1445    No  https://www.alcampo.es/media/h2b/heb/114014668...
# 1446    No  https://www.alcampo.es/media/h69/hf0/956774462...
# 1447    No  https://www.alcampo.es/media/h4c/he1/114014664...
# 1448   Yes  https://www.alcampo.es/media/h64/h89/956780016...
# 1449    No  https://www.alcampo.es/media/h53/h66/114014672...
#
# [1450 rows x 5 columns]

# %%
df_alcampo['Shop'] = 'Alcampo'

today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

alcampo = pd.read_csv("../data/alcampo.csv")
print("File saved",today)
alcampo
# Out:
# File saved 2023-03-14 10:08:54.420400
#        Category                                               Name  \
# 0       Veganos  Bebida de avena con alto contenido de calcio y...
# 1       Veganos  Bebida de soja sin gluten, enriquecida con cal...
# 2       Veganos  Bebida de avena con alto contenido de calcio y...
# 3       Veganos  Bebida de almendras 100% vegetal, sin azúcar n...
# 4       Veganos  Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...         ...                                                ...
# 134632    Sushi  Bandeja con 13 piezas de sushi variado MOWI 33...
# 134633    Sushi  California de Salmón y surimi, con cebolla fri...
# 134634    Sushi  Bandeja con Gyozas (empanadillas) de langostin...
# 134635    Sushi   Maki y California variados SUSHI GOURMET 18 uds.
# 134636    Sushi  Bandeja con 6 piezas de sushi variado MOWI 151 g.
#
#                         Price Stock  \
# 0        5,94 €(0,99 €/Litro)   Yes
# 1        5,34 €(0,89 €/Litro)   Yes
# 2        0,99 €(0,99 €/Litro)   Yes
# 3        2,10 €(2,10 €/Litro)   Yes
# 4       11,22 €(0,18 €/100ml)   Yes
# ...                       ...   ...
# 134632     8,90 €(26,33 €/Kg)    No
# 134633     7,50 €(37,50 €/Kg)    No
# 134634     3,50 €(40,69 €/Kg)    No
# 134635     7,90 €(29,25 €/Kg)   Yes
# 134636     4,90 €(32,45 €/Kg)    No
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 134632  https://www.alcampo.es/media/h2b/heb/114014668...  Alcampo
# 134633  https://www.alcampo.es/media/h69/hf0/956774462...  Alcampo
# 134634  https://www.alcampo.es/media/h4c/he1/114014664...  Alcampo
# 134635  https://www.alcampo.es/media/h64/h89/956780016...  Alcampo
# 134636  https://www.alcampo.es/media/h53/h66/114014672...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 134632  2023-03-14 10:08:54.420400
# 134633  2023-03-14 10:08:54.420400
# 134634  2023-03-14 10:08:54.420400
# 134635  2023-03-14 10:08:54.420400
# 134636  2023-03-14 10:08:54.420400
#
# [134637 rows x 7 columns]
