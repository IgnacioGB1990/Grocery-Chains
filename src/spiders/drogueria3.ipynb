# %%
import pandas as pd
import time
import random

from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()

import pygame
from pygame import mixer

drogueria = {
    # "Lavado de Ropa": "https://www.alcampo.es/compra-online/drogueria/lavado-de-ropa/c/W2104?q=%3Arelevance&page=",
    # "Lavavajillas": "https://www.alcampo.es/compra-online/drogueria/lavavajillas/c/W2106?q=%3Arelevance&page=",
    # "Utensilios Limpieza": "https://www.alcampo.es/compra-online/drogueria/utensilios-limpieza/c/W2109?q=%3Arelevance&page=",
    # "Celulosas": "https://www.alcampo.es/compra-online/drogueria/celulosas/c/W2101?q=%3Arelevance&page=",
    # "Lejías y Amoníacos": "https://www.alcampo.es/compra-online/drogueria/lejias-y-amoniacos/c/W2107?q=%3Arelevance&page=",
    # "Limpieza Calzado": "https://www.alcampo.es/compra-online/drogueria/limpieza-calzado/c/W2105?q=%3Arelevance&page=",
    "Conservación de Alimentos y Moldes": "https://www.alcampo.es/compra-online/drogueria/conservacion-de-alimentos-y-moldes/c/W2102?q=%3Arelevance&page=",
    "Limpieza Hogar": "https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=",
    "Ambientadores": "https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=",
    "Insecticidas" : "https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page="

}


dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in drogueria.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1

df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Conservación de Alimentos y Moldes https://www.alcampo.es/compra-online/drogueria/conservacion-de-alimentos-y-moldes/c/W2102?q=%3Arelevance&page=0
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Conservación de Alimentos y Moldes https://www.alcampo.es/compra-online/drogueria/conservacion-de-alimentos-y-moldes/c/W2102?q=%3Arelevance&page=1
# Category: 66 Name: 66 Image: 66 Price: 66 Stock 66
# Conservación de Alimentos y Moldes https://www.alcampo.es/compra-online/drogueria/conservacion-de-alimentos-y-moldes/c/W2102?q=%3Arelevance&page=2
# No hay más ventanas
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=0
# Category: 114 Name: 114 Image: 114 Price: 114 Stock 114
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=1
# Category: 162 Name: 162 Image: 162 Price: 162 Stock 162
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=2
# Category: 210 Name: 210 Image: 210 Price: 210 Stock 210
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=3
# Category: 258 Name: 258 Image: 258 Price: 258 Stock 258
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=4
# Category: 306 Name: 306 Image: 306 Price: 306 Stock 306
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=5
# Category: 354 Name: 354 Image: 354 Price: 354 Stock 354
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=6
# Category: 393 Name: 393 Image: 393 Price: 393 Stock 393
# Limpieza Hogar https://www.alcampo.es/compra-online/drogueria/limpieza-hogar/c/W2108?q=%3Arelevance&page=7
# No hay más ventanas
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=0
# Category: 441 Name: 441 Image: 441 Price: 441 Stock 441
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=1
# Category: 489 Name: 489 Image: 489 Price: 489 Stock 489
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=2
# Category: 537 Name: 537 Image: 537 Price: 537 Stock 537
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=3
# Category: 585 Name: 585 Image: 585 Price: 585 Stock 585
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=4
# Category: 633 Name: 633 Image: 633 Price: 633 Stock 633
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=5
# Category: 681 Name: 681 Image: 681 Price: 681 Stock 681
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=6
# Category: 729 Name: 729 Image: 729 Price: 729 Stock 729
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=7
# Category: 777 Name: 777 Image: 777 Price: 777 Stock 777
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=8
# Category: 825 Name: 825 Image: 825 Price: 825 Stock 825
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=9
# Category: 873 Name: 873 Image: 873 Price: 873 Stock 873
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=10
# Category: 875 Name: 875 Image: 875 Price: 875 Stock 875
# Ambientadores https://www.alcampo.es/compra-online/drogueria/ambientadores/c/W2110?q=%3Arelevance&page=11
# No hay más ventanas
# Insecticidas https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page=0
# Category: 923 Name: 923 Image: 923 Price: 923 Stock 923
# Insecticidas https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page=1
# Category: 971 Name: 971 Image: 971 Price: 971 Stock 971
# Insecticidas https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page=2
# Category: 989 Name: 989 Image: 989 Price: 989 Stock 989
# Insecticidas https://www.alcampo.es/compra-online/drogueria/insecticidas/c/W2111?q=%3Arelevance&page=3
# No hay más ventanas
#                                Category  \
# 0    Conservación de Alimentos y Moldes
# 1    Conservación de Alimentos y Moldes
# 2    Conservación de Alimentos y Moldes
# 3    Conservación de Alimentos y Moldes
# 4    Conservación de Alimentos y Moldes
# ..                                  ...
# 984                        Insecticidas
# 985                        Insecticidas
# 986                        Insecticidas
# 987                        Insecticidas
# 988                        Insecticidas
#
#                                                   Name                  Price  \
# 0    Bolsas de congelación con zip 1 l. 18 x20 cm P...  1,09 €(0,04 €/Unidad)
# 1    Bolsas de congelación con zip 3 litros 27 x 28...  1,40 €(0,07 €/Unidad)
# 2           Papel de aluminio PRODUCTO ALCAMPO 50 mts.   3,79 €(0,07 €/Metro)
# 3    Papel de horno antiadherente en hojas independ...  0,90 €(0,06 €/Unidad)
# 4    Papel de aluminio PRODUCTO ECONÓMICO ALCAMPO 3...   2,05 €(0,06 €/Metro)
# ..                                                 ...                    ...
# 984  Insecticida especial anticarcoma en aerosol CA...  4,80 €(19,20 €/Litro)
# 985  Insecticida eléctrico antimosquitos en pastill...  2,97 €(0,30 €/Unidad)
# 986         Insecticida aerosol té verde ORION 600 ml.   3,79 €(0,47 €/100ml)
# 987  Recambio de repelente de mosquitos eléctrico e...  5,97 €(0,10 €/Unidad)
# 988  Insecticida aparato + recambio eléctrico RAID ...                 6,93 €
#
#     Stock                                              Image
# 0     Yes  https://www.alcampo.es/media/hc0/h37/997154855...
# 1     Yes  https://www.alcampo.es/media/h36/h89/997161667...
# 2     Yes  https://www.alcampo.es/media/hec/he8/103587841...
# 3     Yes  https://www.alcampo.es/media/hb1/h32/997161848...
# 4     Yes  https://www.alcampo.es/media/h83/h25/110540524...
# ..    ...                                                ...
# 984   Yes  https://www.alcampo.es/media/hb0/h3b/109521181...
# 985   Yes  https://www.alcampo.es/media/he3/hb4/888977109...
# 986   Yes  https://www.alcampo.es/media/h6d/h41/110093756...
# 987   Yes  https://www.alcampo.es/media/he6/h3b/897817237...
# 988   Yes  https://www.alcampo.es/media/he5/haf/108822446...
#
# [989 rows x 5 columns]

# %%
df_alcampo['Shop'] = 'Alcampo'

today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

alcampo = pd.read_csv("../data/alcampo.csv")
print(today)
alcampo
# Out:
# 2023-03-17 13:17:18.437301
#             Category                                               Name  \
# 0            Veganos  Bebida de avena con alto contenido de calcio y...
# 1            Veganos  Bebida de soja sin gluten, enriquecida con cal...
# 2            Veganos  Bebida de avena con alto contenido de calcio y...
# 3            Veganos  Bebida de almendras 100% vegetal, sin azúcar n...
# 4            Veganos  Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...              ...                                                ...
# 180109  Insecticidas  Insecticida especial anticarcoma en aerosol CA...
# 180110  Insecticidas  Insecticida eléctrico antimosquitos en pastill...
# 180111  Insecticidas         Insecticida aerosol té verde ORION 600 ml.
# 180112  Insecticidas  Recambio de repelente de mosquitos eléctrico e...
# 180113  Insecticidas  Insecticida aparato + recambio eléctrico RAID ...
#
#                         Price Stock  \
# 0        5,94 €(0,99 €/Litro)   Yes
# 1        5,34 €(0,89 €/Litro)   Yes
# 2        0,99 €(0,99 €/Litro)   Yes
# 3        2,10 €(2,10 €/Litro)   Yes
# 4       11,22 €(0,18 €/100ml)   Yes
# ...                       ...   ...
# 180109  4,80 €(19,20 €/Litro)   Yes
# 180110  2,97 €(0,30 €/Unidad)   Yes
# 180111   3,79 €(0,47 €/100ml)   Yes
# 180112  5,97 €(0,10 €/Unidad)   Yes
# 180113                 6,93 €   Yes
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 180109  https://www.alcampo.es/media/hb0/h3b/109521181...  Alcampo
# 180110  https://www.alcampo.es/media/he3/hb4/888977109...  Alcampo
# 180111  https://www.alcampo.es/media/h6d/h41/110093756...  Alcampo
# 180112  https://www.alcampo.es/media/he6/h3b/897817237...  Alcampo
# 180113  https://www.alcampo.es/media/he5/haf/108822446...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 180109  2023-03-17 13:17:18.437301
# 180110  2023-03-17 13:17:18.437301
# 180111  2023-03-17 13:17:18.437301
# 180112  2023-03-17 13:17:18.437301
# 180113  2023-03-17 13:17:18.437301
#
# [180114 rows x 7 columns]
