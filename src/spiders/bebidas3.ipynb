# %%
import pandas as pd
import time
import random

from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()


import pygame
from pygame import mixer

bebidas = {
    # "Bebidas refrescantes": "https://www.alcampo.es/compra-online/bebidas/bebidas-refrescantes/c/W1103?q=%3Arelevance&page=",
    # "Cervezas":"https://www.alcampo.es/compra-online/bebidas/cervezas/c/W1107?q=%3Arelevance&page=",
    # "Vino Tinto":"https://www.alcampo.es/compra-online/bebidas/vino-tinto/c/W1151?q=%3Arelevance&page=",
    # "Zumos de Frutas":"https://www.alcampo.es/compra-online/bebidas/zumos-de-frutas/c/W1102?q=%3Arelevance&page=",
    # "Bebidas Alcohólicas":"https://www.alcampo.es/compra-online/bebidas/bebidas-alcoholicas/c/W1154?q=%3Arelevance&page=",
    # "Vino Blanco": "https://www.alcampo.es/compra-online/bebidas/vino-blanco/c/W1152?q=%3Arelevance&page=",
    "Agua, Soda y Gaseosas": "https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=",
    "Licores": "https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=",
    "Vino rosados, frizzantes, dulces y olorosos":"https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=",
    "Champagne Cavas y Sidras": "https://www.alcampo.es/compra-online/bebidas/champagne-cavas-y-sidras/c/W1156?q=%3Arelevance&page=",
}


dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in bebidas.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1

df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Agua, Soda y Gaseosas https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=0
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Agua, Soda y Gaseosas https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=1
# Category: 96 Name: 96 Image: 96 Price: 96 Stock 96
# Agua, Soda y Gaseosas https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=2
# Category: 144 Name: 144 Image: 144 Price: 144 Stock 144
# Agua, Soda y Gaseosas https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=3
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Agua, Soda y Gaseosas https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=4
# Got an attribute error on: https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=4
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Agua, Soda y Gaseosas https://www.alcampo.es/compra-online/bebidas/agua-soda-y-gaseosas/c/W1101?q=%3Arelevance&page=5
# No hay más ventanas
# Licores https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=0
# Got an attribute error on: https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=0
# Category: 192 Name: 192 Image: 192 Price: 192 Stock 192
# Licores https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=1
# Category: 240 Name: 240 Image: 240 Price: 240 Stock 240
# Licores https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=2
# Category: 288 Name: 288 Image: 288 Price: 288 Stock 288
# Licores https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=3
# Category: 320 Name: 320 Image: 320 Price: 320 Stock 320
# Licores https://www.alcampo.es/compra-online/bebidas/licores/c/W1155?q=%3Arelevance&page=4
# No hay más ventanas
# Vino rosados, frizzantes, dulces y olorosos https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=0
# Category: 368 Name: 368 Image: 368 Price: 368 Stock 368
# Vino rosados, frizzantes, dulces y olorosos https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=1
# List index out of range
# Category: 416 Name: 416 Image: 416 Price: 416 Stock 416
# Vino rosados, frizzantes, dulces y olorosos https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=2
# Category: 464 Name: 464 Image: 464 Price: 464 Stock 464
# Vino rosados, frizzantes, dulces y olorosos https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=3
# Category: 512 Name: 512 Image: 512 Price: 512 Stock 512
# Vino rosados, frizzantes, dulces y olorosos https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=4
# List index out of range
# Category: 550 Name: 550 Image: 550 Price: 550 Stock 550
# Vino rosados, frizzantes, dulces y olorosos https://www.alcampo.es/compra-online/bebidas/vino-rosados-frizzantes-dulces-y-olorosos/c/W1153?q=%3Arelevance&page=5
# No hay más ventanas
# Champagne Cavas y Sidras https://www.alcampo.es/compra-online/bebidas/champagne-cavas-y-sidras/c/W1156?q=%3Arelevance&page=0
# List index out of range
# List index out of range
# List index out of range
# List index out of range
# List index out of range
# Category: 598 Name: 598 Image: 598 Price: 598 Stock 598
# Champagne Cavas y Sidras https://www.alcampo.es/compra-online/bebidas/champagne-cavas-y-sidras/c/W1156?q=%3Arelevance&page=1
# List index out of range
# List index out of range
# Category: 646 Name: 646 Image: 646 Price: 646 Stock 646
# Champagne Cavas y Sidras https://www.alcampo.es/compra-online/bebidas/champagne-cavas-y-sidras/c/W1156?q=%3Arelevance&page=2
# List index out of range
# List index out of range
# List index out of range
# List index out of range
# Category: 688 Name: 688 Image: 688 Price: 688 Stock 688
# Champagne Cavas y Sidras https://www.alcampo.es/compra-online/bebidas/champagne-cavas-y-sidras/c/W1156?q=%3Arelevance&page=3
# No hay más ventanas
#                      Category  \
# 0       Agua, Soda y Gaseosas
# 1       Agua, Soda y Gaseosas
# 2       Agua, Soda y Gaseosas
# 3       Agua, Soda y Gaseosas
# 4       Agua, Soda y Gaseosas
# ..                        ...
# 683  Champagne Cavas y Sidras
# 684  Champagne Cavas y Sidras
# 685  Champagne Cavas y Sidras
# 686  Champagne Cavas y Sidras
# 687  Champagne Cavas y Sidras
#
#                                                   Name                 Price  \
# 0    Agua mineral TELENO botella de 1,5 litros pack...  1,98 €(0,22 €/Litro)
# 1              Agua mineral TELENO garrafa de 5 litros  1,38 €(0,27 €/Litro)
# 2    Agua mineral BEZOYA botella de 1,50 l. pack de...  3,76 €(0,41 €/Litro)
# 3         Agua mineral PRODUCTO ALCAMPO garrafa de 8 l  1,24 €(0,15 €/Litro)
# 4    Agua mineral ESMIAGUA botella de 1,5 L, pack d...  1,44 €(0,16 €/Litro)
# ..                                                 ...                   ...
# 683                                      Acumula saldo       (13,26 €/Litro)
# 684  Sidra natural espumosa brut nature con denomin...                6,99 €
# 685  Sidra natural de escanciar, elaborada en Asutr...  2,71 €(3,87 €/Litro)
# 686   Cava brut nature ROYAL CARLTON botella de 75 cl.                8,94 €
# 687  Cava brut imperial reserva ecológico, con deno...                5,59 €
#
#     Stock                                              Image
# 0     Yes  https://www.alcampo.es/media/h35/h90/889502892...
# 1     Yes  https://www.alcampo.es/media/ha0/haa/890179217...
# 2     Yes  https://www.alcampo.es/media/hb3/h1f/937480781...
# 3     Yes  https://www.alcampo.es/media/ha7/h5b/115993799...
# 4     Yes  https://www.alcampo.es/media/h90/h37/118314256...
# ..    ...                                                ...
# 683    No  /compra-online/_ui/desktop/common/images/promo...
# 684    No  https://www.alcampo.es/media/h4b/h4a/975699604...
# 685    No  https://www.alcampo.es/media/h82/h14/115792321...
# 686   Yes  https://www.alcampo.es/media/h49/hf9/895266239...
# 687    No  https://www.alcampo.es/media/ha0/h60/108390790...
#
# [688 rows x 5 columns]

# %%
df_alcampo['Shop'] = 'Alcampo'

today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

alcampo = pd.read_csv("../data/alcampo.csv")
print(today)
alcampo
# Out:
# 2023-03-17 13:01:52.927881
#                         Category  \
# 0                        Veganos
# 1                        Veganos
# 2                        Veganos
# 3                        Veganos
# 4                        Veganos
# ...                          ...
# 166499  Champagne Cavas y Sidras
# 166500  Champagne Cavas y Sidras
# 166501  Champagne Cavas y Sidras
# 166502  Champagne Cavas y Sidras
# 166503  Champagne Cavas y Sidras
#
#                                                      Name  \
# 0       Bebida de avena con alto contenido de calcio y...
# 1       Bebida de soja sin gluten, enriquecida con cal...
# 2       Bebida de avena con alto contenido de calcio y...
# 3       Bebida de almendras 100% vegetal, sin azúcar n...
# 4       Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...                                                   ...
# 166499                                      Acumula saldo
# 166500  Sidra natural espumosa brut nature con denomin...
# 166501  Sidra natural de escanciar, elaborada en Asutr...
# 166502   Cava brut nature ROYAL CARLTON botella de 75 cl.
# 166503  Cava brut imperial reserva ecológico, con deno...
#
#                         Price Stock  \
# 0        5,94 €(0,99 €/Litro)   Yes
# 1        5,34 €(0,89 €/Litro)   Yes
# 2        0,99 €(0,99 €/Litro)   Yes
# 3        2,10 €(2,10 €/Litro)   Yes
# 4       11,22 €(0,18 €/100ml)   Yes
# ...                       ...   ...
# 166499        (13,26 €/Litro)    No
# 166500                 6,99 €    No
# 166501   2,71 €(3,87 €/Litro)    No
# 166502                 8,94 €   Yes
# 166503                 5,59 €    No
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 166499  /compra-online/_ui/desktop/common/images/promo...  Alcampo
# 166500  https://www.alcampo.es/media/h4b/h4a/975699604...  Alcampo
# 166501  https://www.alcampo.es/media/h82/h14/115792321...  Alcampo
# 166502  https://www.alcampo.es/media/h49/hf9/895266239...  Alcampo
# 166503  https://www.alcampo.es/media/ha0/h60/108390790...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 166499  2023-03-17 13:01:52.927881
# 166500  2023-03-17 13:01:52.927881
# 166501  2023-03-17 13:01:52.927881
# 166502  2023-03-17 13:01:52.927881
# 166503  2023-03-17 13:01:52.927881
#
# [166504 rows x 7 columns]
