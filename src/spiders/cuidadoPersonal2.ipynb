# %%
import pandas as pd
import time
import random


from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()

import pygame
from pygame import mixer


cuidadoPersonal = {
    # "Cuidado del cabello" : "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-del-cabello/c/W701?q=%3Arelevance&page=",
    # "Desodorantes" : "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/desodorantes/c/W705?q=%3Arelevance&page=",
    # "Maquillaje": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/maquillaje/c/W708?q=%3Arelevance&page=",

    "Neceseres": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/neceseres/c/W70011?q=%3Arelevance&page=",
    "Cuidado corporal": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=",
    "Cuidado facial": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-facial/c/W706?q=%3Arelevance&page=",

    # "Depilación": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/depilacion/c/W709?q=%3Arelevance&page=",
    # "Colonias": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=",
    # "Higiene bucal": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=",
    
    # "Afeitado y cuidado masculino": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=",
    # "Higiene íntima": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=",
    # "Solares":"https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/solares/c/W70012?q=%3Arelevance&page="

}



dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in cuidadoPersonal.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1
    


df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Neceseres https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/neceseres/c/W70011?q=%3Arelevance&page=0
# Category: 12 Name: 12 Image: 12 Price: 12 Stock 12
# Neceseres https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/neceseres/c/W70011?q=%3Arelevance&page=1
# No hay más ventanas
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=0
# Category: 60 Name: 60 Image: 60 Price: 60 Stock 60
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=1
# Category: 108 Name: 108 Image: 108 Price: 108 Stock 108
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=2
# Category: 156 Name: 156 Image: 156 Price: 156 Stock 156
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=3
# Category: 204 Name: 204 Image: 204 Price: 204 Stock 204
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=4
# Category: 252 Name: 252 Image: 252 Price: 252 Stock 252
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=5
# Category: 300 Name: 300 Image: 300 Price: 300 Stock 300
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=6
# Category: 348 Name: 348 Image: 348 Price: 348 Stock 348
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=7
# Category: 396 Name: 396 Image: 396 Price: 396 Stock 396
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=8
# Category: 444 Name: 444 Image: 444 Price: 444 Stock 444
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=9
# Category: 492 Name: 492 Image: 492 Price: 492 Stock 492
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=10
# Category: 540 Name: 540 Image: 540 Price: 540 Stock 540
# Cuidado corporal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=11
# No hay más ventanas
# Cuidado facial https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-facial/c/W706?q=%3Arelevance&page=0
# 884  https://www.alcampo.es/media/h4a/hcd/114707603...
# 885  https://www.alcampo.es/media/he3/h0c/119312580...
#
# [886 rows x 5 columns]

# %%
# Add Alcampo name
df_alcampo['Shop'] = 'Alcampo'

# Add timestamp
today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

# Append to existing csv file
df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# Read in csv to save as excel as well
# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

# Read Alcampo csv
alcampo = pd.read_csv("../data/alcampo.csv")
print("Appended",today)
alcampo
# Out:
# Appended 2023-03-17 13:08:50.363025
#               Category                                               Name  \
# 0              Veganos  Bebida de avena con alto contenido de calcio y...
# 1              Veganos  Bebida de soja sin gluten, enriquecida con cal...
# 2              Veganos  Bebida de avena con alto contenido de calcio y...
# 3              Veganos  Bebida de almendras 100% vegetal, sin azúcar n...
# 4              Veganos  Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...                ...                                                ...
# 167385  Cuidado facial  Crema antimanchas con FPS 15 (bajo) DIADERMINE...
# 167386  Cuidado facial  Crema nutrición intensa y reparadora de día, p...
# 167387  Cuidado facial  Crema hidratante dúo anti-envejecimiento diari...
# 167388  Cuidado facial  Gel exfoliante de uso diario, anti puntos negr...
# 167389  Cuidado facial  Neceser con crema de día (50 ml) y crema de no...
#
#                          Price Stock  \
# 0         5,94 €(0,99 €/Litro)   Yes
# 1         5,34 €(0,89 €/Litro)   Yes
# 2         0,99 €(0,99 €/Litro)   Yes
# 3         2,10 €(2,10 €/Litro)   Yes
# 4        11,22 €(0,18 €/100ml)   Yes
# ...                        ...   ...
# 167385  11,44 €(22,88 €/100ml)   Yes
# 167386  15,38 €(30,76 €/100ml)    No
# 167387                 18,04 €   Yes
# 167388    8,50 €(5,66 €/100ml)   Yes
# 167389                 27,99 €   Yes
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 167385  https://www.alcampo.es/media/he5/hec/110157379...  Alcampo
# 167386  https://www.alcampo.es/media/haf/hb7/106494109...  Alcampo
# 167387  https://www.alcampo.es/media/h7e/hfb/105488488...  Alcampo
# 167388  https://www.alcampo.es/media/h4a/hcd/114707603...  Alcampo
# 167389  https://www.alcampo.es/media/he3/h0c/119312580...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 167385  2023-03-17 13:08:50.363025
# 167386  2023-03-17 13:08:50.363025
# 167387  2023-03-17 13:08:50.363025
# 167388  2023-03-17 13:08:50.363025
# 167389  2023-03-17 13:08:50.363025
#
# [167390 rows x 7 columns]
