# %%
import pandas as pd
import time
import random


from bs4 import BeautifulSoup as bs
import requests
import numpy as np

from IPython.display import display
from datetime import datetime

from dotenv import load_dotenv
import os
load_dotenv()

import pygame
from pygame import mixer


cuidadoPersonal = {
    # "Cuidado del cabello" : "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-del-cabello/c/W701?q=%3Arelevance&page=",
    # "Desodorantes" : "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/desodorantes/c/W705?q=%3Arelevance&page=",
    # "Maquillaje": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/maquillaje/c/W708?q=%3Arelevance&page=",

    # "Neceseres": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/neceseres/c/W70011?q=%3Arelevance&page=",
    # "Cuidado corporal": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-corporal/c/W702?q=%3Arelevance&page=",
    # "Cuidado facial": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/cuidado-facial/c/W706?q=%3Arelevance&page=",

    "Depilación": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/depilacion/c/W709?q=%3Arelevance&page=",
    "Colonias": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=",
    "Higiene bucal": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=",
    
    # "Afeitado y cuidado masculino": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/afeitado-y-cuidado-masculino/c/W707?q=%3Arelevance&page=",
    # "Higiene íntima": "https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-intima/c/W70013?q=%3Arelevance&page=",
    # "Solares":"https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/solares/c/W70012?q=%3Arelevance&page="

}



dict_alcampo = {"Category": [], "Name":[],"Price":[],"Stock":[], "Image":[]}

for i in cuidadoPersonal.items():

    categoria = i[0]
    url_to_scrape = i[1]
    contador = 0
    product_not_found = 10

    while product_not_found != "0":
        
        url = url_to_scrape+ f"{contador}"
        response = requests.get(url='https://proxy.scrapeops.io/v1/',params={'api_key': os.environ["SCARPE_OPS_API_KEY"],'url': url, },)
        html = response.content
        soup = bs(html,"lxml")
     
        print(categoria,url)
        try:
            product_not_found = soup.find("div",class_="totalResults").get_text(strip=True, separator='').split(" ")[0]
        except:
            print("Got an attribute error on:",url)

        if product_not_found =="0":
            print("No hay más ventanas")
            break
        
        else:
            products = soup.find_all("div",class_="productGridItemContainer")
            prices = soup.find_all("div",class_="priceContainer")
            stock_available = soup.find_all("div",class_="cart add")

            for product in products:

                dict_alcampo["Name"].append(product.find("span").get_text(strip=True))
                dict_alcampo["Image"].append(product.find("img")["src"])

                dict_alcampo["Category"].append(categoria)

            for price in prices:
                try:
                    dict_alcampo["Price"].append(price.find_all("span")[2].get_text(strip=True))
                except:
                    print("List index out of range")
                    dict_alcampo["Price"].append("NaN")

            for stock in stock_available:
                
                stock_yes_no = stock.find_all("button")[2].get_text(strip=True).split(" "[0])
                
                if stock_yes_no[0]=="Sin":
                    dict_alcampo["Stock"].append("No")
                else:
                    dict_alcampo["Stock"].append("Yes")
                              
            print( "Category:", len(dict_alcampo["Category"]), "Name:", len(dict_alcampo["Name"]) ,"Image:",len(dict_alcampo["Image"]),"Price:", len(dict_alcampo["Price"]), "Stock",len(dict_alcampo["Stock"])    )
            
        contador+=1
    


df_alcampo = pd.DataFrame(dict_alcampo)

#Play sound when completed
mixer.init()
mixer.music.load(".././assets/completed.mp3")
mixer.music.set_volume(0.4)
mixer.music.play()  

df_alcampo
# Out:
# Depilación https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/depilacion/c/W709?q=%3Arelevance&page=0
# Category: 48 Name: 48 Image: 48 Price: 48 Stock 48
# Depilación https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/depilacion/c/W709?q=%3Arelevance&page=1
# Category: 71 Name: 71 Image: 71 Price: 71 Stock 71
# Depilación https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/depilacion/c/W709?q=%3Arelevance&page=2
# No hay más ventanas
# Colonias https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=0
# Category: 119 Name: 119 Image: 119 Price: 119 Stock 119
# Colonias https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=1
# Category: 167 Name: 167 Image: 167 Price: 167 Stock 167
# Colonias https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=2
# Category: 215 Name: 215 Image: 215 Price: 215 Stock 215
# Colonias https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=3
# Category: 263 Name: 263 Image: 263 Price: 263 Stock 263
# Colonias https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=4
# Category: 302 Name: 302 Image: 302 Price: 302 Stock 302
# Colonias https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/colonias/c/W7010?q=%3Arelevance&page=5
# No hay más ventanas
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=0
# Category: 350 Name: 350 Image: 350 Price: 350 Stock 350
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=1
# Category: 398 Name: 398 Image: 398 Price: 398 Stock 398
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=2
# Category: 446 Name: 446 Image: 446 Price: 446 Stock 446
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=3
# Category: 494 Name: 494 Image: 494 Price: 494 Stock 494
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=4
# Category: 542 Name: 542 Image: 542 Price: 542 Stock 542
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=5
# Category: 590 Name: 590 Image: 590 Price: 590 Stock 590
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=6
# List index out of range
# List index out of range
# Category: 637 Name: 637 Image: 637 Price: 637 Stock 637
# Higiene bucal https://www.alcampo.es/compra-online/cuidado-personal/perfumeria/higiene-bucal/c/W704?q=%3Arelevance&page=7
# No hay más ventanas
#           Category                                               Name  \
# 0       Depilación  Cuchillas desechables con cabezal de 2 hojas, ...
# 1       Depilación  Bandas depilatorias faciales con aloe vera, es...
# 2       Depilación  Recambio con 3 hojas para máquinillas de depli...
# 3       Depilación  Cuchillas desechables con aloe vera y aceite i...
# 4       Depilación  Cuchillas desechables con cabezal pivotante de...
# ..             ...                                                ...
# 632  Higiene bucal  Cepillo de dientes con filamentos suaves, espe...
# 633  Higiene bucal  Gel bioadhesivo con ácido hialuróncio PERIO-AI...
# 634  Higiene bucal  Cepillo de dientes a pilas, con filamentos sua...
# 635  Higiene bucal  Cepillo dental eléctrico e irrigador bucal Bra...
# 636  Higiene bucal  Recambio irrigador ORAL-B Oxyjet ED17-4, micro...
#
#                       Price Stock  \
# 0     0,99 €(0,20 €/Unidad)   Yes
# 1     1,49 €(0,07 €/Unidad)   Yes
# 2    12,92 €(3,23 €/Unidad)   Yes
# 3     2,55 €(0,51 €/Unidad)   Yes
# 4     1,78 €(0,45 €/Unidad)   Yes
# ..                      ...   ...
# 632                  2,66 €   Yes
# 633                 10,99 €   Yes
# 634                  7,99 €   Yes
# 635                    129€   Yes
# 636                 16,90 €   Yes
#
#                                                  Image
# 0    https://www.alcampo.es/media/h8b/h78/110114152...
# 1    https://www.alcampo.es/media/hde/h2a/912943860...
# 2    https://www.alcampo.es/media/h8e/hdf/108168928...
# 3    https://www.alcampo.es/media/h7f/h87/104447057...
# 4    https://www.alcampo.es/media/h42/h44/112060101...
# ..                                                 ...
# 632  https://www.alcampo.es/media/h19/hbf/935552090...
# 633  https://www.alcampo.es/media/h07/hab/930408474...
# 634  https://www.alcampo.es/media/h06/hf9/928077345...
# 635  https://www.alcampo.es/media/h98/h6a/917470560...
# 636  https://www.alcampo.es/media/ha6/h26/937838228...
#
# [637 rows x 5 columns]

# %%
# Add Alcampo name
df_alcampo['Shop'] = 'Alcampo'

# Add timestamp
today = pd.Timestamp.now()
df_alcampo['Date'] = today
df_alcampo

# Append to existing csv file
df_alcampo.to_csv("../data/alcampo.csv", mode='a', index=False, header=False)

# Read in csv to save as excel as well
# read_file = pd.read_csv ("../data/alcampo.csv")
# read_file.to_excel ("../data/alcampo.xlsx", index = None, header=True)

# Read Alcampo csv
alcampo = pd.read_csv("../data/alcampo.csv")
print("Appended",today)
alcampo
# Out:
# Appended 2023-03-17 13:13:24.765641
#              Category                                               Name  \
# 0             Veganos  Bebida de avena con alto contenido de calcio y...
# 1             Veganos  Bebida de soja sin gluten, enriquecida con cal...
# 2             Veganos  Bebida de avena con alto contenido de calcio y...
# 3             Veganos  Bebida de almendras 100% vegetal, sin azúcar n...
# 4             Veganos  Bebida de avena ALCAMPO ECOLÓGICO brick de 1 l...
# ...               ...                                                ...
# 174383  Higiene bucal  Cepillo de dientes con filamentos suaves, espe...
# 174384  Higiene bucal  Gel bioadhesivo con ácido hialuróncio PERIO-AI...
# 174385  Higiene bucal  Cepillo de dientes a pilas, con filamentos sua...
# 174386  Higiene bucal  Cepillo dental eléctrico e irrigador bucal Bra...
# 174387  Higiene bucal  Recambio irrigador ORAL-B Oxyjet ED17-4, micro...
#
#                         Price Stock  \
# 0        5,94 €(0,99 €/Litro)   Yes
# 1        5,34 €(0,89 €/Litro)   Yes
# 2        0,99 €(0,99 €/Litro)   Yes
# 3        2,10 €(2,10 €/Litro)   Yes
# 4       11,22 €(0,18 €/100ml)   Yes
# ...                       ...   ...
# 174383                 2,66 €   Yes
# 174384                10,99 €   Yes
# 174385                 7,99 €   Yes
# 174386                   129€   Yes
# 174387                16,90 €   Yes
#
#                                                     Image     Shop  \
# 0       https://www.alcampo.es/media/hbc/hc7/114853804...  Alcampo
# 1       https://www.alcampo.es/media/h2b/hc3/107936543...  Alcampo
# 2       https://www.alcampo.es/media/hc3/h79/109357267...  Alcampo
# 3       https://www.alcampo.es/media/h31/h28/114171706...  Alcampo
# 4       https://www.alcampo.es/media/hb5/h66/111936354...  Alcampo
# ...                                                   ...      ...
# 174383  https://www.alcampo.es/media/h19/hbf/935552090...  Alcampo
# 174384  https://www.alcampo.es/media/h07/hab/930408474...  Alcampo
# 174385  https://www.alcampo.es/media/h06/hf9/928077345...  Alcampo
# 174386  https://www.alcampo.es/media/h98/h6a/917470560...  Alcampo
# 174387  https://www.alcampo.es/media/ha6/h26/937838228...  Alcampo
#
#                               Date
# 0       2023-03-08 19:51:25.159831
# 1       2023-03-08 19:51:25.159831
# 2       2023-03-08 19:51:25.159831
# 3       2023-03-08 19:51:25.159831
# 4       2023-03-08 19:51:25.159831
# ...                            ...
# 174383  2023-03-17 13:13:24.765641
# 174384  2023-03-17 13:13:24.765641
# 174385  2023-03-17 13:13:24.765641
# 174386  2023-03-17 13:13:24.765641
# 174387  2023-03-17 13:13:24.765641
#
# [174388 rows x 7 columns]
