# %%
import numpy as np
import pandas as pd

df = pd.read_csv("dataCleaned/all_data.csv",parse_dates=["Fecha"])
df
# Out:
#        Supermercado                       Categoría  \
# 0         Mercadona  Aceite Vinagre Salsas Especias
# 1         Mercadona  Aceite Vinagre Salsas Especias
# 2         Mercadona  Aceite Vinagre Salsas Especias
# 3         Mercadona  Aceite Vinagre Salsas Especias
# 4         Mercadona  Aceite Vinagre Salsas Especias
# ...             ...                             ...
# 216382      Alcampo                 Fresco al Corte
# 216383      Alcampo                 Fresco al Corte
# 216384      Alcampo                 Fresco al Corte
# 216385      Alcampo                 Fresco al Corte
# 216386      Alcampo                 Fresco al Corte
#
#                                                  Producto  Precio (€)  \
# 0              Aceite de oliva 0,4º Hacendado Garrafa 5 L       23.63
# 1              Aceite de oliva 0,4º Hacendado Botella 1 L        4.77
# 2       Aceite de oliva virgen extra Hacendado Garrafa...       16.75
# ...

# %%
df.drop_duplicates(subset = "Producto")
# Out:
#        Supermercado                       Categoría  \
# 0         Mercadona  Aceite Vinagre Salsas Especias
# 1         Mercadona  Aceite Vinagre Salsas Especias
# 2         Mercadona  Aceite Vinagre Salsas Especias
# 3         Mercadona  Aceite Vinagre Salsas Especias
# 4         Mercadona  Aceite Vinagre Salsas Especias
# ...             ...                             ...
# 215847      Alcampo               Marisco y pescado
# 215850      Alcampo               Marisco y pescado
# 215854      Alcampo               Marisco y pescado
# 216130      Alcampo               Marisco y pescado
# 216198      Alcampo               Marisco y pescado
#
#                                                  Producto  Precio (€)  \
# 0              Aceite de oliva 0,4º Hacendado Garrafa 5 L       23.63
# 1              Aceite de oliva 0,4º Hacendado Botella 1 L        4.77
# 2       Aceite de oliva virgen extra Hacendado Garrafa...       16.75
# ...

# %%
df
# Out:
#        Supermercado                       Categoría  \
# 0         Mercadona  Aceite Vinagre Salsas Especias
# 1         Mercadona  Aceite Vinagre Salsas Especias
# 2         Mercadona  Aceite Vinagre Salsas Especias
# 3         Mercadona  Aceite Vinagre Salsas Especias
# 4         Mercadona  Aceite Vinagre Salsas Especias
# ...             ...                             ...
# 216382      Alcampo                 Fresco al Corte
# 216383      Alcampo                 Fresco al Corte
# 216384      Alcampo                 Fresco al Corte
# 216385      Alcampo                 Fresco al Corte
# 216386      Alcampo                 Fresco al Corte
#
#                                                  Producto  Precio (€)  \
# 0              Aceite de oliva 0,4º Hacendado Garrafa 5 L       23.63
# 1              Aceite de oliva 0,4º Hacendado Botella 1 L        4.77
# 2       Aceite de oliva virgen extra Hacendado Garrafa...       16.75
# ...

# %%
df["Fecha"] = df["Fecha"].dt.strftime('%d-%m-%Y')
df
# Out:
#        Supermercado                       Categoría  \
# 0         Mercadona  Aceite Vinagre Salsas Especias
# 1         Mercadona  Aceite Vinagre Salsas Especias
# 2         Mercadona  Aceite Vinagre Salsas Especias
# 3         Mercadona  Aceite Vinagre Salsas Especias
# 4         Mercadona  Aceite Vinagre Salsas Especias
# ...             ...                             ...
# 125898      Alcampo                 Fresco al Corte
# 125899      Alcampo                 Fresco al Corte
# 125900      Alcampo                 Fresco al Corte
# 125901      Alcampo                 Fresco al Corte
# 125902      Alcampo                 Fresco al Corte
#
#                                                  Producto  Precio (€)  \
# 0              Aceite de oliva 0,4º Hacendado Garrafa 5 L       23.63
# 1              Aceite de oliva 0,4º Hacendado Botella 1 L        4.77
# 2       Aceite de oliva virgen extra Hacendado Garrafa...       16.75
# ...

# %%
today = df.copy()
today.drop(today[today['Fecha'] != "12-03-2023"].index, inplace = True)
today
# Out:
# Empty DataFrame
# Columns: [Supermercado, Categoría, Producto, Precio (€), Fecha]
# Index: []

# %%
# Out:
#        Supermercado                       Categoría  \
# 0         Mercadona  Aceite Vinagre Salsas Especias
# 1         Mercadona  Aceite Vinagre Salsas Especias
# 2         Mercadona  Aceite Vinagre Salsas Especias
# 3         Mercadona  Aceite Vinagre Salsas Especias
# 4         Mercadona  Aceite Vinagre Salsas Especias
# ...             ...                             ...
# 216382      Alcampo                 Fresco al Corte
# 216383      Alcampo                 Fresco al Corte
# 216384      Alcampo                 Fresco al Corte
# 216385      Alcampo                 Fresco al Corte
# 216386      Alcampo                 Fresco al Corte
#
#                                                  Producto  Precio (€)  \
# 0              Aceite de oliva 0,4º Hacendado Garrafa 5 L       23.63
# 1              Aceite de oliva 0,4º Hacendado Botella 1 L        4.77
# 2       Aceite de oliva virgen extra Hacendado Garrafa...       16.75
# ...
