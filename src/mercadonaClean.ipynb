# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Step 1: Clean Mercadona csv

# %%
df = pd.read_csv("./data/mercadona.csv")
original_df = df.count()
print(original_df)
df.head()
# Out:
# Group       26740
# Category    26740
# Name        26740
# Size        26740
# Price       26740
# Image       26740
# Shop        26740
# Date        26740
# dtype: int64
#                        Group               Category  \
# 0  Aceite, especias y salsas  Aceite, vinagre y sal
# 1  Aceite, especias y salsas  Aceite, vinagre y sal
# 2  Aceite, especias y salsas  Aceite, vinagre y sal
# 3  Aceite, especias y salsas  Aceite, vinagre y sal
# 4  Aceite, especias y salsas  Aceite, vinagre y sal
#
#                                                 Name            Size  \
# 0                     Aceite de oliva 0,4º Hacendado     Garrafa 5 L
# 1                     Aceite de oliva 0,4º Hacendado     Botella 1 L
# 2             Aceite de oliva virgen extra Hacendado     Garrafa 3 L
# 3             Aceite de oliva virgen extra Hacendado     Botella 1 L
# 4  Aceite de oliva virgen extra Hacendado Gran Se...  Botella 750 ml
#
#           Price                                              Image       Shop  \
# 0  23,63 € /ud.  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 1   4,77 € /ud.  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 2  16,75 € /ud.  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 3   5,63 € /ud.  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 4   5,11 € /ud.  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
#
#                          Date
# 0  2023-03-06 19:51:58.387060
# 1  2023-03-06 19:51:58.387060
# 2  2023-03-06 19:51:58.387060
# 3  2023-03-06 19:51:58.387060
# 4  2023-03-06 19:51:58.387060

# %% [markdown]
# ### Price format

# %%
# Replace , with . , splits into array, gets first number 
df["Price"] = df["Price"].apply(lambda x: x.replace(",",".").split(" ")[0])
df["Price"].head()
# Out:
# 0    23.63
# 1     4.77
# 2    16.75
# 3     5.63
# 4     5.11
# Name: Price, dtype: object

# %%
# Shows all values that are strings 
df[df["Price"].apply(lambda x: "." not in x)].head()
# Out:
#                               Group               Category  \
# 5519      Aceite, especias y salsas           Otras salsas
# 6064  Azúcar, caramelos y chocolate              Chocolate
# 6156  Azúcar, caramelos y chocolate              Golosinas
# 6170  Azúcar, caramelos y chocolate       Mermelada y miel
# 6193                           Bebé  Alimentación infantil
#
#                                                    Name     Size    Price  \
# 5519                              Salsa brava Hacendado  Novedad     Bote
# 6064  Chocolate negro 92% cacao Hacendado 0% azúcare...  Novedad  Tableta
# 6156                 Golosinas Rega Black Mix Hacendado  Novedad  Paquete
# 6170                   Mermelada de frambuesa Hacendado  Novedad    Tarro
# 6193  Papilla guisantes tiernos con jamón Hero baby ...  Novedad  Tarrito
#
#                                                   Image       Shop  \
# 5519  ......  Mercadona
# 6064  https://prod-mercadona.imgix.net/images/aa3a4c...  Mercadona
# 6156  https://prod-mercadona.imgix.net/images/2de5d5...  Mercadona
# 6170  https://prod-mercadona.imgix.net/images/a6f0f0...  Mercadona
# 6193  https://prod-mercadona.imgix.net/images/9f4217...  Mercadona
#
#                             Date
# 5519  2023-03-07 17:13:53.556398
# 6064  2023-03-07 17:13:53.556398
# 6156  2023-03-07 17:13:53.556398
# 6170  2023-03-07 17:13:53.556398
# 6193  2023-03-07 17:13:53.556398

# %%
#Using drop() to delete rows based on column value
df.drop(df[df["Price"].apply(lambda x: "." not in x)].index,inplace =True)
df.drop(df[df["Price"].apply(lambda x: len(x)>6)].index,inplace =True)

# %%
print("Original DF",original_df[0])
print("After",df.count()[0])
df.head()
# Out:
# Original DF 26740
# After 26687
#                        Group               Category  \
# 0  Aceite, especias y salsas  Aceite, vinagre y sal
# 1  Aceite, especias y salsas  Aceite, vinagre y sal
# 2  Aceite, especias y salsas  Aceite, vinagre y sal
# 3  Aceite, especias y salsas  Aceite, vinagre y sal
# 4  Aceite, especias y salsas  Aceite, vinagre y sal
#
#                                                 Name            Size  Price  \
# 0                     Aceite de oliva 0,4º Hacendado     Garrafa 5 L  23.63
# 1                     Aceite de oliva 0,4º Hacendado     Botella 1 L   4.77
# 2             Aceite de oliva virgen extra Hacendado     Garrafa 3 L  16.75
# 3             Aceite de oliva virgen extra Hacendado     Botella 1 L   5.63
# 4  Aceite de oliva virgen extra Hacendado Gran Se...  Botella 750 ml   5.11
#
#                                                Image       Shop  \
# 0  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 1  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 2  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 3  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 4  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
#
#                          Date
# 0  2023-03-06 19:51:58.387060
# 1  2023-03-06 19:51:58.387060
# 2  2023-03-06 19:51:58.387060
# 3  2023-03-06 19:51:58.387060
# 4  2023-03-06 19:51:58.387060

# %%
# Convert all prices to floats !
df["Price"] = df["Price"].astype(float)
df[df["Price"]>330]
# Out:
#                       Group       Category  \
# 1897   Charcutería y quesos  Jamón serrano
# 1898   Charcutería y quesos  Jamón serrano
# 7251   Charcutería y quesos  Jamón serrano
# 7252   Charcutería y quesos  Jamón serrano
# 12598  Charcutería y quesos  Jamón serrano
# 12599  Charcutería y quesos  Jamón serrano
# 17940  Charcutería y quesos  Jamón serrano
# 17941  Charcutería y quesos  Jamón serrano
# 23287  Charcutería y quesos  Jamón serrano
# 23288  Charcutería y quesos  Jamón serrano
#
#                                                     Name                 Size  \
# 1897   Jamón de bellota ibérico 50% La Hacienda del i...    Pieza 9 kg aprox.
# 1898     Jamón de bellota ibérico 100% Campo Extremadura  Pieza 9,5 kg aprox.
# 7251   Jamón de bellota ibérico 50% La Hacienda del i...    Pieza 9 kg aprox.
# 7252     Jamón de bellota ibérico 100% Campo Extremadura  Pieza 9,5 kg aprox.
# 12598  Jamón de bellota ibérico 50% La Hacienda del i...    Pieza 9 kg aprox.
# 12599    Jamón de bellota ibérico 100% Campo Extremadura  Pieza 9,5 kg aprox.
# 17940  Jamón de bellota ibérico 50% La Hacienda del i...    Pieza 9 kg aprox.
# 17941    Jamón de bellota ibérico 100% Campo Extremadura  Pieza 9,5 kg aprox.
# 23287  Jamón de bellota ibérico 50% La Hacienda del i...    Pieza 9 kg aprox.
# 23288    Jamón de bellota ibérico 100% Campo Extremadura  Pieza 9,5 kg aprox.
#
#         Price                                              Image       Shop  \
# 1897   369.00  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 1898   479.75  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 7251   369.00  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 7252   479.75  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 12598  369.00  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 12599  479.75  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 17940  369.00  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 17941  479.75  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 23287  369.00  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
# 23288  479.75  https://prod-mercadona.imgix.net/images/46f3bc...  Mercadona
#
#                              Date
# 1897   2023-03-06 19:51:58.387060
# 1898   2023-03-06 19:51:58.387060
# 7251   2023-03-07 17:13:53.556398
# 7252   2023-03-07 17:13:53.556398
# 12598  2023-03-08 16:27:45.530967
# 12599  2023-03-08 16:27:45.530967
# 17940  2023-03-09 16:55:36.373420
# 17941  2023-03-09 16:55:36.373420
# 23287  2023-03-10 16:45:24.410621
# 23288  2023-03-10 16:45:24.410621

# %%
# Size handling
df["Unit_size"]= df["Size"].apply(lambda x: x.replace(",",".").split(" "))
df
# Out:
#                            Group                Category  \
# 0      Aceite, especias y salsas   Aceite, vinagre y sal
# 1      Aceite, especias y salsas   Aceite, vinagre y sal
# 2      Aceite, especias y salsas   Aceite, vinagre y sal
# 3      Aceite, especias y salsas   Aceite, vinagre y sal
# 4      Aceite, especias y salsas   Aceite, vinagre y sal
# ...                          ...                     ...
# 26735                      Zumos  Tomate y otros sabores
# 26736                      Zumos  Tomate y otros sabores
# 26737                      Zumos  Tomate y otros sabores
# 26738                      Zumos  Tomate y otros sabores
# 26739                      Zumos  Tomate y otros sabores
#
#                                                     Name            Size  \
# 0                         Aceite de oliva 0,4º Hacendado     Garrafa 5 L
# 1                         Aceite de oliva 0,4º Hacendado     Botella 1 L
# 2                 Aceite de oliva virgen extra Hacendado     Garrafa 3 L
# 3                 Aceite de oliva virgen extra Hacendado     Botella 1 L
# 4      Aceite de oliva virgen extra Hacendado Gran Se...  Botella 750 ml
# ...                                                  ...             ...
# 26735   Bebida de pomelo Hacendado sin azúcares añadidos       Brick 1 L
# 26736     Bebida guayaba Hacendado sin azúcares añadidos       Brick 1 L
# 26737     Bebida de pera Hacendado sin azúcares añadidos       Brick 1 L
# 26738                           Zumo de pomelo Hacendado       Brick 1 L
# 26739                Zumo de manzana selección Hacendado       Brick 1 L
#
#        Price                                              Image       Shop  \
# 0      23.63  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 1       4.77  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 2      16.75  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 3       5.63  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# 4       5.11  https://prod-mercadona.imgix.net/images/e4b36f...  Mercadona
# ...      ...                                                ...        ...
# 26735   1.25  https://prod-mercadona.imgix.net/images/ec1076...  Mercadona
# 26736   1.30  https://prod-mercadona.imgix.net/images/ec1076...  Mercadona
# 26737   1.10  https://prod-mercadona.imgix.net/images/ec1076...  Mercadona
# 26738   1.45  https://prod-mercadona.imgix.net/images/ec1076...  Mercadona
# 26739   1.50  https://prod-mercadona.imgix.net/images/ec1076...  Mercadona
#
#                              Date           Unit_size
# 0      2023-03-06 19:51:58.387060     [Garrafa, 5, L]
# 1      2023-03-06 19:51:58.387060     [Botella, 1, L]
# 2      2023-03-06 19:51:58.387060     [Garrafa, 3, L]
# 3      2023-03-06 19:51:58.387060     [Botella, 1, L]
# 4      2023-03-06 19:51:58.387060  [Botella, 750, ml]
# ...                           ...                 ...
# 26735  2023-03-10 16:45:24.410621       [Brick, 1, L]
# 26736  2023-03-10 16:45:24.410621       [Brick, 1, L]
# 26737  2023-03-10 16:45:24.410621       [Brick, 1, L]
# 26738  2023-03-10 16:45:24.410621       [Brick, 1, L]
# 26739  2023-03-10 16:45:24.410621       [Brick, 1, L]
#
# [26687 rows x 9 columns]

# %%
df["Unit_size"].apply(lambda x: x[1])
# Out:
# 0          5
# 1          1
# 2          3
# 3          1
# 4        750
#         ...
# 26735      1
# 26736      1
# 26737      1
# 26738      1
# 26739      1
# Name: Unit_size, Length: 26687, dtype: object

# %%
array = ["Garrafa", 5, "L"]
[int(s) for s in array if s.isnumeric()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j0/w6j4gtqn3qgbyxvxzx172r_m0000gn/T/ipykernel_50465/2263884952.py in <module>
#       1 array = ["Garrafa", 5, "L"]
# ----> 2 [int(s) for s in array if s.isnumeric()]
#
# /var/folders/j0/w6j4gtqn3qgbyxvxzx172r_m0000gn/T/ipykernel_50465/2263884952.py in <listcomp>(.0)
#       1 array = ["Garrafa", 5, "L"]
# ----> 2 [int(s) for s in array if s.isnumeric()]
#
# AttributeError: 'int' object has no attribute 'isnumeric'

# %%
def format_size(row):
    if

df.apply(format_size,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j0/w6j4gtqn3qgbyxvxzx172r_m0000gn/T/ipykernel_50465/3544978579.py in <module>
#       2     print("Hello")
#       3
# ----> 4 df.apply(format_size,axis=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# TypeError: format_size() takes 0 positional arguments but 1 was given

# %%
# If € not in array remove:

df.loc[df['Price'].isin(["Bote"])]
# Out:
# Empty DataFrame
# Columns: [Group, Category, Name, Size, Price, Image, Shop, Date]
# Index: []

# %%
df[df["Name"].str.contains("Agua")]
# Out:
#                   Group                      Category  \
# 166    Agua y refrescos                          Agua
# 167    Agua y refrescos                          Agua
# 168    Agua y refrescos                          Agua
# 169    Agua y refrescos                          Agua
# 170    Agua y refrescos                          Agua
# ...                 ...                           ...
# 19847  Limpieza y hogar  Detergente y suavizante ropa
# 19848  Limpieza y hogar  Detergente y suavizante ropa
# 19849  Limpieza y hogar  Detergente y suavizante ropa
# 20672          Mascotas                          Gato
# 20723          Mascotas                         Perro
#
#                                                    Name  \
# 166                          Agua mineral grande Bezoya
# 167                          Agua mineral grande Bezoya
# 168                        Agua mineral grande Fondetal
# 169                        Agua mineral grande Fondetal
# 170                       Agua mineral mediana Fondetal
# ...                                                 ...
# 19847                       Agua destilada Bosque Verde
# 19848                       Agua destilada Bosque Verde
# 19849  Agua de plancha Bosque Verde perfume ropa limpia
# 20672       Agua de colonia para perros y gatos Krislin
# 20723       Agua de colonia para perros y gatos Krislin
#
#                            Size  Price  \
# 166    [6, botellas, x, 1.5, L]   4.38
# 167           [Botella, 1.5, L]   0.73
# 168    [6, botellas, x, 1.5, L]   2.22
# 169           [Botella, 1.5, L]   0.37
# 170      [6, botellas, x, 1, L]   3.00
# ...                         ...    ...
# 19847           [Garrafa, 5, L]   2.10
# 19848           [Garrafa, 2, L]   0.90
# 19849           [Botella, 1, L]   0.65
# 20672          [Spray, 250, ml]   3.40
# 20723          [Spray, 250, ml]   3.40
#
#                                                    Image       Shop  \
# 166    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 167    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 168    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 169    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 170    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# ...                                                  ...        ...
# 19847  https://prod-mercadona.imgix.net/images/1537dd...  Mercadona
# 19848  https://prod-mercadona.imgix.net/images/1537dd...  Mercadona
# 19849  https://prod-mercadona.imgix.net/images/1537dd...  Mercadona
# 20672  https://prod-mercadona.imgix.net/images/2391d7...  Mercadona
# 20723  https://prod-mercadona.imgix.net/images/da3f03...  Mercadona
#
#                              Date
# 166    2023-03-06 19:51:58.387060
# 167    2023-03-06 19:51:58.387060
# 168    2023-03-06 19:51:58.387060
# 169    2023-03-06 19:51:58.387060
# 170    2023-03-06 19:51:58.387060
# ...                           ...
# 19847  2023-03-09 16:55:36.373420
# 19848  2023-03-09 16:55:36.373420
# 19849  2023-03-09 16:55:36.373420
# 20672  2023-03-09 16:55:36.373420
# 20723  2023-03-09 16:55:36.373420
#
# [236 rows x 8 columns]

# %%
df[df["Name"].str.contains("Agua ")]
# Out:
#                   Group                      Category  \
# 166    Agua y refrescos                          Agua
# 167    Agua y refrescos                          Agua
# 168    Agua y refrescos                          Agua
# 169    Agua y refrescos                          Agua
# 170    Agua y refrescos                          Agua
# ...                 ...                           ...
# 19847  Limpieza y hogar  Detergente y suavizante ropa
# 19848  Limpieza y hogar  Detergente y suavizante ropa
# 19849  Limpieza y hogar  Detergente y suavizante ropa
# 20672          Mascotas                          Gato
# 20723          Mascotas                         Perro
#
#                                                    Name  \
# 166                          Agua mineral grande Bezoya
# 167                          Agua mineral grande Bezoya
# 168                        Agua mineral grande Fondetal
# 169                        Agua mineral grande Fondetal
# 170                       Agua mineral mediana Fondetal
# ...                                                 ...
# 19847                       Agua destilada Bosque Verde
# 19848                       Agua destilada Bosque Verde
# 19849  Agua de plancha Bosque Verde perfume ropa limpia
# 20672       Agua de colonia para perros y gatos Krislin
# 20723       Agua de colonia para perros y gatos Krislin
#
#                            Size  Price  \
# 166    [6, botellas, x, 1.5, L]   4.38
# 167           [Botella, 1.5, L]   0.73
# 168    [6, botellas, x, 1.5, L]   2.22
# 169           [Botella, 1.5, L]   0.37
# 170      [6, botellas, x, 1, L]   3.00
# ...                         ...    ...
# 19847           [Garrafa, 5, L]   2.10
# 19848           [Garrafa, 2, L]   0.90
# 19849           [Botella, 1, L]   0.65
# 20672          [Spray, 250, ml]   3.40
# 20723          [Spray, 250, ml]   3.40
#
#                                                    Image       Shop  \
# 166    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 167    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 168    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 169    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# 170    https://prod-mercadona.imgix.net/images/58bec2...  Mercadona
# ...                                                  ...        ...
# 19847  https://prod-mercadona.imgix.net/images/1537dd...  Mercadona
# 19848  https://prod-mercadona.imgix.net/images/1537dd...  Mercadona
# 19849  https://prod-mercadona.imgix.net/images/1537dd...  Mercadona
# 20672  https://prod-mercadona.imgix.net/images/2391d7...  Mercadona
# 20723  https://prod-mercadona.imgix.net/images/da3f03...  Mercadona
#
#                              Date
# 166    2023-03-06 19:51:58.387060
# 167    2023-03-06 19:51:58.387060
# 168    2023-03-06 19:51:58.387060
# 169    2023-03-06 19:51:58.387060
# 170    2023-03-06 19:51:58.387060
# ...                           ...
# 19847  2023-03-09 16:55:36.373420
# 19848  2023-03-09 16:55:36.373420
# 19849  2023-03-09 16:55:36.373420
# 20672  2023-03-09 16:55:36.373420
# 20723  2023-03-09 16:55:36.373420
#
# [224 rows x 8 columns]

# %%
df[df["Price"].apply(lambda x: "." not in x)].count()
# Out:
# Group       0
# Category    0
# Name        0
# Size        0
# Price       0
# Image       0
# Shop        0
# Date        0
# dtype: int64
